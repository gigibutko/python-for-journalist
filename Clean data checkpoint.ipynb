# %% [markdown]
# This dataset is from the Stanford Open Policing Project. I cleaned it up, but still left a lot of rows so I could have options. The rows left are date, location of stop, sex, race, and result of stop. [This will take you to where I got the raw data.](https://openpolicing.stanford.edu/data/) [This will take you to the google file with the raw data](https://docs.google.com/spreadsheets/d/1cwHoWinU_EYAOVIoeLeEC2KDp2eQ82eNuEZgtUyx8a8/edit?usp=sharing)

# %% [markdown]
# [This will take you to "clean" dataset](https://docs.google.com/spreadsheets/d/13_BAkr_yYJ2WUEbC0JmWCkeZMNOm3OmUP3Rv9T1QKPE/edit?usp=sharing)
#
# This dataset is only kind of "clean," because I am still working on gathering data for what I am going to ask of the data. I deleted all the data that I know I am not going to need, and will probably end up deleting even more. I am currently putting together, based on press releases and news articles, a list of the major "diversity" initiatives that the police have put into place between the years 2012 and 2016. Using that list, I am going to chart whether or not these diversity initatives actually help. I think, based on what I know of the data right now, I am going to use stop rates as my indicator, as black drivers are consistently stoped more than white drivers. More specifically, I am hoping to cut it down even more to where we are only looking at drivers stopped for "moving violations." However, I might change it up and look at drivers who are stopped for moving violations and then searched as the data shows that you are more likely to be searched if you are black than white once stopped for a moving violation.

# %%
import pandas as pd

# %%
df.raw = pd.read_csv('oh_columbus_2020_04_01.csv')
df.raw.head(10)
# Out:
#   raw_row_number        date      time                        location  \
# 0          1|2|3  2012-01-01  01:16:00        livingston and carpenter
# 1              4  2012-01-01  01:20:00      E 16th Ave and Waldeck Ave
# 2              5  2012-01-01  07:54:00          king ave and cannon dr
# 3              6  2012-01-01  10:00:00     James rd and Livingston ave
# 4              7  2012-01-01  10:50:00   N Wilson Road and Twin Creeks
# 5              8  2012-01-01  11:23:00    rhoads ave and e whittier st
# 6              9  2012-01-01  11:32:00       n high st and arcadia ave
# 7             10  2012-01-01  15:01:00  Williams Rd and S. Hamilton Rd
# 8             11  2012-01-01  15:38:00      ATCHESON ST and ellison st
# 9             12  2012-01-01  17:15:00             Audubon and Arcadia
#
#          lat        lng  precinct  zone subject_race subject_sex       type  \
# 0  39.949920 -82.975067      11.0   5.0        white      female  vehicular
# ...

# %%
df.raw.tail(10)
# Out:
#               raw_row_number        date      time  \
# 128147                152369  2016-12-30  20:13:00
# 128148                152370  2016-12-30  20:15:00
# 128149                152371  2016-12-30  20:35:00
# 128150                152372  2016-12-30  21:01:00
# 128151                152373  2016-12-30  21:29:00
# 128152                152374  2016-12-30  22:29:00
# 128153                152375  2016-12-30  22:30:00
# 128154                152376  2016-12-30  22:40:00
# 128155                152377  2016-12-30  22:41:00
# 128156  152378|152379|152380  2016-12-30  22:41:00
#
#                                   location        lat        lng  precinct  \
# 128147    n high st and broad meadows blvd  40.072921 -83.018954       3.0
# 128148          Dresden St and Maynard Ave  40.009767 -82.972675       5.0
# 128149  e maynard ave and hiawatha park dr  40.010519 -82.987252       5.0
# 128150                 sullivant and helen  39.949092 -83.043972       8.0
# ...

# %%
df.raw.shape
# Out:
# (128157, 18)

# %%
dfclean = pd.read_csv('cleanoh_columbus_2020_04_01.csv')
dfclean.head(10)
# Out:
#          date                        location  precinct subject_race  \
# 0  2012-01-01        livingston and carpenter      11.0        white
# 1  2012-01-01      E 16th Ave and Waldeck Ave       4.0        white
# 2  2012-01-01          king ave and cannon dr       NaN        black
# 3  2012-01-01     James rd and Livingston ave       9.0        black
# 4  2012-01-01   N Wilson Road and Twin Creeks      15.0        black
# 5  2012-01-01    rhoads ave and e whittier st      11.0        black
# 6  2012-01-01       n high st and arcadia ave       3.0        white
# 7  2012-01-01  Williams Rd and S. Hamilton Rd      20.0        black
# 8  2012-01-01      ATCHESON ST and ellison st       7.0        black
# 9  2012-01-01             Audubon and Arcadia       2.0        white
#
#   subject_sex       type  arrest_made  citation_issued  warning_issued  \
# 0      female  vehicular         True            False           False
# ...

# %%
dfclean.tail(10)
# Out:
#               date                            location  precinct subject_race  \
# 128147  2016-12-30    n high st and broad meadows blvd       3.0        white
# 128148  2016-12-30          Dresden St and Maynard Ave       5.0        black
# 128149  2016-12-30  e maynard ave and hiawatha park dr       5.0        white
# 128150  2016-12-30                 sullivant and helen       8.0        white
# 128151  2016-12-30      E North Broadway and N High St       3.0        white
# 128152  2016-12-30            Summit St and E 11th Ave       4.0        black
# 128153  2016-12-30       E Weber RD and IR 71 N/B Ramp       NaN        other
# 128154  2016-12-30   Hall Rd and Georgesville Green DR      10.0        white
# 128155  2016-12-30      Demorest Rd and Vanderberg Ave      10.0        white
# 128156  2016-12-30       CLEVELAND AV and ASHBURY ROAD      18.0        black
#
#        subject_sex       type  arrest_made  citation_issued  warning_issued  \
# ...

# %%
dfclean.shape
# Out:
# (128157, 12)

# %%
dfMini.to_csv('Clean data checkpoint.csv', encoding='utf8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-38fd78bd19f3> in <module>
# ----> 1 dfMini.to_csv('Clean data checkpoint.csv', encoding='utf8')
#
# NameError: name 'dfMini' is not defined

# %%
ls
# Out:
# 2 Clean data-Copy1.ipynb
# 2 Clean data.ipynb
# Clean data checkpoint.ipynb
# Data Check In.ipynb
# Hello Python! - in class 3.11.21.ipynb
# Python Challenge 1.ipynb
# Raw Dataset .ipynb
# Test Notebook.ipynb
# cleanoh_columbus_2020_04_01.csv
# fatal-police-shootings-data.csv
# oh_columbus_2020_04_01.csv
# pls let me make a dataset.ipynb
# results.csv
# yg821jf8611_oh_columbus_2020_04_01.csv.zip
